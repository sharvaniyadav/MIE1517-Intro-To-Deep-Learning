# %% [markdown]
# <a href="https://colab.research.google.com/github/sharvaniyadav/MIE1517-Intro-To-Deep-Learning/blob/main/%5BMIE1517%5D_A2_SharvaniYadav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2: Hand Gesture Recognition [50 Pt]
#
# This assignment will be completed in two parts. In Part A you will gain experience gathering your own data set (specifically images of hand gestures), and understand the challenges involved in the data cleaning process. In Part B you will train a convolutional neural network to make classifications on different hand gestures. By the end of this assignment, you should be able to:
#
# 1. Generate and preprocess your own data
# 2. Load and split data for training, validation and testing
# 3. Train a Convolutional Neural Network
# 4. Apply transfer learning to improve your model
#
# Note that for this assignment we will not be providing you with any starter code. You should be able to take the sample code provided in the preparation sample code, previous assignment, and lectures and modify it accordingly to complete the tasks outlined below.
#
# *This assignment is based on an assignment developed by Prof. Lisa Zhang.*
#
# ### What to submit
#
# **Submission for Part A:**
# Submit a zip file containing your images. Three images each of American Sign Language gestures for letters A - I (total of 27 images). You will be required to clean the images before submitting them. Details are provided under Part A of the handout.
#
# Individual image file names should follow the convention of student-number_Alphabet_file-number.jpg
# (e.g. 100343434_A_1.jpg).
#
#
# **Submission for Part B:**
# Submit an HTML file containing all your code, outputs, and write-up
# from parts A and B. You can produce a HTML file directly from Google Colab. The Colab instructions are provided at the end of this document.
#
# **Do not submit any other files produced by your code.**
#
# Include a link to your colab file in your submission.
#
# Please use Google Colab to complete this assignment. If you want to use Jupyter Notebook, please complete the assignment and upload your Jupyter Notebook file to Google Colab for submission.

# %% [markdown]
# ## Colab Link
#
# Include a link to your colab file here and ensure the file can be accessed by the our teaching team.

# %%
# TO BE COMPLETED

http://

# %% [markdown]
# # Part A. Data Collection [5pt]
#
# So far, we have worked with data sets that have been collected, cleaned, and curated by machine learning
# researchers and practitioners. Datasets like MNIST and CIFAR are often used as toy examples, both by
# students and by researchers testing new machine learning models.
#
# In the real world, getting a clean data set is never that easy. More than half the work in applying machine
# learning is finding, gathering, cleaning, and formatting your data set.
#
# The purpose of this assignment is to help you gain experience gathering your own data set, and understand the
# challenges involved in the data cleaning process.
#
# ### American Sign Language
#
# American Sign Language (ASL) is a complete, complex language that employs signs made by moving the
# hands combined with facial expressions and postures of the body. It is the primary language of many
# North Americans who are deaf and is one of several communication options used by people who are deaf or
# hard-of-hearing.
#
# The hand gestures representing English alphabet are shown below. This assignment focuses on classifying a subset
# of these hand gesture images using convolutional neural networks. Specifically, given an image of a hand
# showing one of the letters A-I, we want to detect which letter is being represented.
#
# ![alt text](https://www.disabled-world.com/pics/1/asl-alphabet.jpg)
#
#
# ### Generating Data
# We will produce the images required to assess our models by ourselves. You are required to collect, clean and submit
# three images each of Americal Sign Language gestures for letters A - I (total of 27 images)
# Steps involved in data collection
#
# 1. Familiarize yourself with American Sign Language gestures for letters from A - I (9 letters).
# 2. Take three pictures at slightly different orientation for each letter gesture using your
# mobile phone.
#  - Ensure adequate lighting while you are capturing the images.
#  - Use a white wall as your background.
#  - Use your right hand to create gestures (for consistency).
#  - Keep your right hand fairly apart from your body and any other obstructions.
#  - Avoid having shadows on parts of your hand.
# 3. Transfer the images to your laptop for cleaning.
#
# ### Cleaning Data
# To simplify the machine learning the task, we will standardize the training images. We will make sure that
# all our images are of the same size (224 x 224 pixels RGB), and have the hand in the center of the cropped
# regions.
#
# You may use the following applications to crop and resize your images:
#
# **Mac**
# - Use Preview:
# – Holding down CMD + Shift will keep a square aspect ratio while selecting the hand area.
# – Resize to 224x224 pixels.
#
# **Windows 10**
# - Use Photos app to edit and crop the image and keep the aspect ratio a square.
# - Use Paint to resize the image to the final image size of 224x224 pixels.
#
# **Linux**
# - You can use GIMP, imagemagick, or other tools of your choosing.
# You may also use online tools such as http://picresize.com
# All the above steps are illustrative only. You need not follow these steps but following these will ensure that
# you produce a good quality dataset. You will be judged based on the quality of the images alone.
# Please do not edit your photos in any other way. You should not need to change the aspect ratio of your
# image. You also should not digitally remove the background or shadows—instead, take photos with a white
# background and minimal shadows.
#
# ### Accepted Images
# Images will be accepted and graded based on the criteria below
# 1. The final image should be size 224x224 pixels (RGB).
# 2. The file format should be a .jpg file.
# 3. The hand should be approximately centered on the frame.
# 4. The hand should not be obscured or cut off.
# 5. The photos follows the ASL gestures posted earlier.
# 6. The photos were not edited in any other way (e.g. no electronic removal of shadows or background).
#
# ### Submission
# Submit a zip file containing your images. There should be a total of 27 images (3 for each category)
# 1. Individual image file names should follow the convention of student-number_Alphabet_file-number.jpg
# (e.g. 100343434_A_1.jpg)
# 2. Zip all the images together and name it with the following convention: last-name_student-number.zip
# (e.g. last-name_100343434.zip).
# 3. Submit the zipped folder.
#
# ![alt text](https://github.com/UTNeural/APS360/blob/master/Gesture%20Images.PNG?raw=true)

# %% [markdown]
# # Part B. Building a CNN [45pt]
#
# For this assignment, we are not going to give you any starter code. You will be writing a convolutional neural network
# from scratch. You are welcome to modify and combine code provided previously in the course (assignments, preparation code, lectures, etc.). You can also write your own code.
#
# You may use the PyTorch documentation freely. You might also find online tutorials helpful. However, all code that you submit must be be your own. You cannot take a completed assignment and claim it as your own.
#
# Make sure that your code is vectorized, and does not contain obvious inefficiencies (for example, unecessary
# for loops, or unnecessary calls to unsqueeze()). Ensure enough comments are included in the code so that
# your TA can understand what you are doing. It is your responsibility to show that you understand what you
# write.
#
# **This is much more challenging and time-consuming than the previous assignments.** Make sure that you give yourself plenty of time by starting early.

# %% [markdown]
# ## Part 1. Data Loading and Splitting [3pt EXPLORATORY]
#
# Download the anonymized data provided on Quercus. Split the data into training, validation, and test sets.
#
# Note: Data splitting is not as trivial in this assignment. We want our test set to closely resemble the setting in which
# our model will be used. In particular, our test set should contain hands that are never seen in training!
#
# Explain how you split the data, either by describing what you did, or by showing the code that you used.
# Justify your choice of splitting strategy. How many training, validation, and test images do you have?
#
# For loading the data, you can use plt.imread, or any other method that you choose. You may find
# torchvision.datasets.ImageFolder helpful. (see https://pytorch.org/vision/main/generated/torchvision.datasets.ImageFolder.html)
# )

# %%
# Part B.1 — Data Loading and Subject-Based Splitting
# In this section, the dataset was unzipped, loaded, split by subject into train/val/test (70/15/15),
# the class counts were shown, the split was saved, DataLoaders were created, and a quick check was done for overlap.

# Step 1: Importing Necessary Libraries
# These libraries were used for file handling, data loading, transforms, and splitting by subject.
import os, json, random, collections, zipfile
from pathlib import Path

import numpy as np
import torch
from torch.utils.data import Subset, DataLoader
from torchvision import datasets, transforms
from sklearn.model_selection import GroupShuffleSplit

# Step 2: Unzipping the Dataset and Setting the Root Path
# The dataset zip file was already in the Colab environment.
# It was unzipped into /content if it wasn’t already, and the root path was set.
zip_path = "/content/A2_Hand_Gesture_Dataset_revised.zip"
unzip_root = "/content"

if not os.path.exists(os.path.join(unzip_root, "Lab_3b_Gesture_Dataset Revised")):
    with zipfile.ZipFile(zip_path, 'r') as zf:
        zf.extractall(unzip_root)
    print("[INFO] Dataset unzipped.")
else:
    print("[INFO] Dataset already unzipped.")

DATA_ROOT = "/content/Lab_3b_Gesture_Dataset Revised"
print(f"[INFO] DATA_ROOT = {DATA_ROOT}")

# Step 3: Setting Random Seeds and Defining Transforms
# Fixed seeds were set to make sure the split is always the same.
# A simple transform was used to resize images and convert them to tensors.
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Step 4: Loading the Dataset
# The dataset had folders for each class (A–I).
# ImageFolder assigned labels based on these folders.
full_ds = datasets.ImageFolder(root=DATA_ROOT, transform=transform)
class_names = full_ds.classes
print("[INFO] Classes:", class_names)
print("[INFO] Total Images:", len(full_ds))

# Step 5: Extracting Subject IDs
# Each filename had a subject ID at the start, before the first underscore.
# These IDs were used to split the data by subject.
def get_subject_id(path_str):
    stem = Path(path_str).stem
    return stem.split("_")[0].lower()

subjects = [get_subject_id(fp) for fp, _ in full_ds.samples]
unique_subjects = sorted(set(subjects))
print(f"[INFO] Number of Unique Subjects: {len(unique_subjects)}")

# Step 6: Splitting the Dataset by Subject (70/15/15)
# GroupShuffleSplit was used so that all images from one subject stay in the same set.
# 15% of subjects were used for test, and the rest were split into train and val.
idx_all = np.arange(len(full_ds))
groups = np.array(subjects)

# Test split
gss1 = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=seed)
trainval_idx, test_idx = next(gss1.split(idx_all, groups=groups))

# Validation split
val_rel = 0.15 / (1 - 0.15)
gss2 = GroupShuffleSplit(n_splits=1, test_size=val_rel, random_state=seed)
train_idx_rel, val_idx_rel = next(gss2.split(trainval_idx, groups=groups[trainval_idx]))

train_idx = trainval_idx[train_idx_rel]
val_idx = trainval_idx[val_idx_rel]

print(f"[INFO] Split Sizes -> Train: {len(train_idx)} | Val: {len(val_idx)} | Test: {len(test_idx)}")

# Step 7: Showing Class Counts and Saving the Split
# The number of images per class was printed for each split.
# The split indices were saved to a JSON file to reuse later.
def counts_by_class(ds, idxs):
    counter = collections.Counter(int(ds[i][1]) for i in idxs)
    return {ds.classes[k]: counter.get(k, 0) for k in range(len(ds.classes))}

def summarize(name, idxs):
    print(f"\n[{name.upper()}] Total Images: {len(idxs)}")
    counts = counts_by_class(full_ds, idxs)
    for c in full_ds.classes:
        print(f"  {c}: {counts[c]}")
    return counts

train_counts = summarize("train", train_idx)
val_counts = summarize("val", val_idx)
test_counts = summarize("test", test_idx)

split_file = "/content/subject_disjoint_split.json"
with open(split_file, "w") as f:
    json.dump({
        "classes": class_names,
        "train_idx": train_idx.tolist(),
        "val_idx": val_idx.tolist(),
        "test_idx": test_idx.tolist(),
        "seed": seed
    }, f, indent=2)
print(f"\n[INFO] Split saved to {split_file}")

# Step 8: Creating Subsets and DataLoaders
# Subsets were made for each split, and DataLoaders were created to load data during training.
train_ds = Subset(full_ds, train_idx)
val_ds = Subset(full_ds, val_idx)
test_ds = Subset(full_ds, test_idx)

def make_loader(ds, bs=32, shuffle=False, nw=2):
    return DataLoader(ds, batch_size=bs, shuffle=shuffle, num_workers=nw, pin_memory=True)

batch_size = 32
train_loader = make_loader(train_ds, bs=batch_size, shuffle=True)
val_loader = make_loader(val_ds, bs=batch_size)
test_loader = make_loader(test_ds, bs=batch_size)
print("[INFO] DataLoaders Ready.")

# Step 9: Checking for Subject Overlap
# A quick check was done to make sure subjects don’t appear in more than one split.
def subject_set(subset):
    return set(get_subject_id(full_ds.samples[i][0]) for i in subset.indices)

subj_train = subject_set(train_ds)
subj_val = subject_set(val_ds)
subj_test = subject_set(test_ds)

print(f"[CHECK] Train ∩ Val = {len(subj_train & subj_val)}")
print(f"[CHECK] Train ∩ Test = {len(subj_train & subj_test)}")
print(f"[CHECK] Val ∩ Test = {len(subj_val & subj_test)}")
# Out:
# [INFO] Dataset unzipped.
# [INFO] DATA_ROOT = /content/Lab_3b_Gesture_Dataset Revised
# [INFO] Classes: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# [INFO] Total Images: 2432
# [INFO] Number of Unique Subjects: 92
# [INFO] Split Sizes -> Train: 1683 | Val: 378 | Test: 371
#
# [TRAIN] Total Images: 1683
#   A: 188
#   B: 189
#   C: 189
#   D: 190
#   E: 189
#   F: 189
#   G: 189
#   H: 189
#   I: 171
#
# [VAL] Total Images: 378
#   A: 42
#   B: 42
#   C: 42
#   D: 42
#   E: 42
#   F: 42
#   G: 42
#   H: 42
#   I: 42
#
# [TEST] Total Images: 371
#   A: 42
#   B: 42
#   C: 42
#   D: 42
#   E: 41
#   F: 42
#   G: 42
#   H: 42
#   I: 36
#
# [INFO] Split saved to /content/subject_disjoint_split.json
# [INFO] DataLoaders Ready.
# [CHECK] Train ∩ Val = 0
# [CHECK] Train ∩ Test = 0
# [CHECK] Val ∩ Test = 0

# %%
'''
PROVIDE YOUR ANSWER BELOW

The dataset was first unzipped and its structure was inspected to confirm that it contained gesture images for classes A to I.
Each image filename contained a subject ID, which was used to split the data by subject instead of by individual images. A subject-disjoint split was then created with 70% of the
subjects assigned to the training set, 15% to the validation set, and 15% to the test set.
A 70/15/15 ratio was chosen to keep a balanced amount of data for both validation and testing, while still maintaining enough training samples for the model to learn effectively.
This is different from a standard 80/20 split because a separate validation set is needed to tune hyperparameters and prevent overfitting, while also keeping the test set completely
unseen for evaluation. Splitting by subject ensures that the model does not see the same hands in both training and testing, which aligns with the assignment requirement. After the split,
the data for each set was saved in separate folders and transformed to 224×224 pixels before being loaded using ImageFolder.
The final split contained 1,683 training images, 378 validation images, and 371 test images, with balanced class distributions across sets.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nThe dataset was first unzipped and its structure was inspected to confirm that it contained gesture images for classes A to I.\nEach image filename contained a subject ID, which was used to split the data by subject instead of by individual images. A subject-disjoint split was then created with 70% of the\nsubjects assigned to the training set, 15% to the validation set, and 15% to the test set.\nA 70/15/15 ratio was chosen to keep a balanced amount of data for both validation and testing, while still maintaining enough training samples for the model to learn effectively.\nThis is different from a standard 80/20 split because a separate validation set is needed to tune hyperparameters and prevent overfitting, while also keeping the test set completely\nunseen for evaluation. Splitting by subject ensures that the model does not see the same hands in both training and testing, which aligns with the assignment requirement. After the split,\nthe data for e
# ...

# %% [markdown]
# ## Part 2. Model Building and Sanity Checking [5pt]
#
# ### Part (i) Convolutional Network [2pt MODEL]
#
# Build a convolutional neural network model that takes the (224x224 RGB) image as input, and predicts the gesture
# letter. Your model should be a subclass of nn.Module. Explain your choice of neural network architecture: how
# many layers did you choose? What types of layers did you use? Were they fully-connected or convolutional?
# What about other decisions like pooling layers, activation functions, number of channels / hidden units?

# %%
# PART B.2(i) — BUILDING THE CONVOLUTIONAL NEURAL NETWORK MODEL
# This model took 224x224 RGB images as input and produced logits for 9 gesture classes (A–I)

import torch
import torch.nn as nn
import torch.nn.functional as F

class GestureCNN(nn.Module):
    def __init__(self, dropout_p: float = 0.4):
        super().__init__()
        # Block 1: Applied Conv → BN → ReLU → MaxPool (224x224x3 → 112x112x32)
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1   = nn.BatchNorm2d(32)

        # Block 2: Applied Conv → BN → ReLU → MaxPool (112x112x32 → 56x56x64)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2   = nn.BatchNorm2d(64)

        # Block 3: Applied Conv → BN → ReLU → MaxPool (56x56x64 → 28x28x128)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3   = nn.BatchNorm2d(128)

        # Used MaxPooling to reduce spatial size and Global Average Pooling to flatten to 128-D
        self.pool  = nn.MaxPool2d(2, 2)
        self.gap   = nn.AdaptiveAvgPool2d(1)

        # Defined Fully Connected Layers for final classification (128 → 128 → 9)
        self.fc1   = nn.Linear(128, 128)
        self.drop  = nn.Dropout(dropout_p)
        self.fc2   = nn.Linear(128, 9)

    def forward(self, x):
        # Passed input through each block
        x = self.pool(F.relu(self.bn1(self.conv1(x))))  # Block 1
        x = self.pool(F.relu(self.bn2(self.conv2(x))))  # Block 2
        x = self.pool(F.relu(self.bn3(self.conv3(x))))  # Block 3

        # Applied Global Average Pooling and flattened output
        x = self.gap(x).flatten(1)

        # Passed through FC layers with ReLU and Dropout
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = self.fc2(x)
        return x

# Quick shape check to verify output dimension was correct
if __name__ == "__main__":
    model = GestureCNN()
    out = model(torch.randn(2, 3, 224, 224))
    print("Output shape:", out.shape)
# Out:
# Output shape: torch.Size([2, 9])

# %%
'''
PROVIDE YOUR ANSWER BELOW

The model used is a custom convolutional neural network built as a subclass of nn.Module. It takes 224×224
RGB images as input and predicts one of 9 gesture classes.
The architecture consists of three convolutional layers followed by two fully connected layers.
Each convolutional layer uses 3×3 filters, with the number of channels
increasing from 32 to 64 to 128 as the network goes deeper.
This allows the model to learn simple features in the early layers and more complex patterns in later layers.

After each convolutional layer, ReLU activation is applied to introduce non-linearity,
and a 2×2 max pooling layer is used to reduce the spatial dimensions by half.
This helps control the number of parameters and makes the network more efficient. After the final convolution block,
global average pooling is applied to reduce the 28×28×128 feature map into a 128-dimensional vector.
This avoids flattening a large feature map and keeps the fully connected layers smaller and easier to train.

The classifier consists of two fully connected layers with 128 hidden units and dropout for regularization.
The final layer outputs 9 logits, one for each gesture class (A–I).
The design is simple but effective: convolutional layers extract spatial features,
ReLU provides non-linearity, max pooling reduces size, and the fully connected layers perform the classification.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nThe model used is a custom convolutional neural network built as a subclass of nn.Module. It takes 224×224\nRGB images as input and predicts one of 9 gesture classes.\nThe architecture consists of three convolutional layers followed by two fully connected layers.\nEach convolutional layer uses 3×3 filters, with the number of channels\nincreasing from 32 to 64 to 128 as the network goes deeper.\nThis allows the model to learn simple features in the early layers and more complex patterns in later layers.\n\nAfter each convolutional layer, ReLU activation is applied to introduce non-linearity,\nand a 2×2 max pooling layer is used to reduce the spatial dimensions by half.\nThis helps control the number of parameters and makes the network more efficient. After the final convolution block,\nglobal average pooling is applied to reduce the 28×28×128 feature map into a 128-dimensional vector.\nThis avoids flattening a large feature map and keeps the fully conne
# ...

# %% [markdown]
# ### Part (ii) Training Code [2pt MODEL]
#
# Write code that trains your neural network given some training data. Your training code should make it easy
# to tweak the usual hyperparameters, like batch size, learning rate, and the model object itself. Make sure
# that you are checkpointing your models from time to time (the frequency is up to you). Explain your choice
# of loss function and optimizer.

# %%
# PART B.2(ii) — TRAINING CODE (EASY HYPERPARAMETERS + CHECKPOINTS)
# This code trained the CNN on the subject-disjoint split and saved checkpoints during training.

import torch
import torch.nn as nn
from torch.optim import Adam
from torch.optim.lr_scheduler import StepLR
from pathlib import Path
import time

# Step 1: Defined loss function and a small accuracy helper
criterion = nn.CrossEntropyLoss()

def batch_accuracy(logits, targets):
    preds = logits.argmax(1)
    return (preds == targets).float().mean().item()

# Step 2: Wrote a single-epoch training loop
def train_one_epoch(model, loader, optimizer, device):
    model.train()
    total_loss, total_acc, total_n = 0.0, 0.0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        bs = y.size(0)
        total_loss += loss.item() * bs
        total_acc  += batch_accuracy(logits, y) * bs
        total_n    += bs
    return total_loss / total_n, total_acc / total_n

# Step 3: Wrote an evaluation loop (no gradients)
@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    total_loss, total_acc, total_n = 0.0, 0.0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = criterion(logits, y)

        bs = y.size(0)
        total_loss += loss.item() * bs
        total_acc  += batch_accuracy(logits, y) * bs
        total_n    += bs
    return total_loss / total_n, total_acc / total_n

# Step 4: Wrapped training with hyperparameters and checkpoint saving
def train_model(
    model,
    train_loader,
    val_loader,
    device,
    *,
    epochs=15,            # easy to change
    lr=3e-4,              # easy to change
    weight_decay=1e-4,    # L2 regularization
    step_size=5,          # drop LR every 'step_size' epochs
    gamma=0.5,            # multiply LR by this factor
    ckpt_dir="/content/checkpoints",
    ckpt_every=5          # save every N epochs
):
    optimizer = Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = StepLR(optimizer, step_size=step_size, gamma=gamma)

    Path(ckpt_dir).mkdir(parents=True, exist_ok=True)
    best_val_acc, best_path = 0.0, None

    for epoch in range(1, epochs + 1):
        t0 = time.time()
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device)
        val_loss,   val_acc   = evaluate(model, val_loader, device)
        scheduler.step()
        dt = time.time() - t0

        print(f"Epoch {epoch:02d} | "
              f"Train Loss {train_loss:.4f} Acc {train_acc:.2%} | "
              f"Val Loss {val_loss:.4f} Acc {val_acc:.2%} | "
              f"{dt:.1f}s")

        # Saved periodic checkpoint
        if epoch % ckpt_every == 0:
            path = f"{ckpt_dir}/gesturecnn_epoch{epoch:02d}.pt"
            torch.save({
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "scheduler_state": scheduler.state_dict()
            }, path)
            print(f"[INFO] Saved checkpoint to {path}")

        # Saved best model based on validation accuracy
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_path = f"{ckpt_dir}/gesturecnn_best.pt"
            torch.save({
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "scheduler_state": scheduler.state_dict()
            }, best_path)
            print(f"[INFO] Updated best model (Val Acc {best_val_acc:.2%})")

    print(f"[INFO] Best validation accuracy: {best_val_acc:.2%}")
    return best_path

# Step 5: Chose device, created model, and started training (hyperparameters are easy to tweak)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = GestureCNN().to(device)

best_ckpt = train_model(
    model,
    train_loader,
    val_loader,
    device,
    epochs=15,
    lr=3e-4,
    weight_decay=1e-4,
    step_size=5,
    gamma=0.5,
    ckpt_dir="/content/checkpoints",
    ckpt_every=5
)
print("Best checkpoint path:", best_ckpt)
# Out:
# Epoch 01 | Train Loss 2.1815 Acc 15.15% | Val Loss 2.1725 Acc 16.67% | 7.0s
# [INFO] Updated best model (Val Acc 16.67%)
# Epoch 02 | Train Loss 2.1105 Acc 19.96% | Val Loss 2.1652 Acc 13.49% | 6.8s
# Epoch 03 | Train Loss 1.9785 Acc 27.51% | Val Loss 2.0581 Acc 19.31% | 5.2s
# [INFO] Updated best model (Val Acc 19.31%)
# Epoch 04 | Train Loss 1.8570 Acc 28.40% | Val Loss 1.9538 Acc 25.66% | 4.7s
# [INFO] Updated best model (Val Acc 25.66%)
# Epoch 05 | Train Loss 1.7654 Acc 31.31% | Val Loss 2.0602 Acc 24.60% | 4.4s
# [INFO] Saved checkpoint to /content/checkpoints/gesturecnn_epoch05.pt
# Epoch 06 | Train Loss 1.7077 Acc 34.64% | Val Loss 1.8881 Acc 33.07% | 4.2s
# [INFO] Updated best model (Val Acc 33.07%)
# Epoch 07 | Train Loss 1.6529 Acc 37.08% | Val Loss 1.8970 Acc 30.69% | 5.0s
# Epoch 08 | Train Loss 1.6304 Acc 37.49% | Val Loss 1.9207 Acc 31.75% | 4.2s
# Epoch 09 | Train Loss 1.6077 Acc 35.89% | Val Loss 1.9085 Acc 36.24% | 4.2s
# [INFO] Updated best model (Val Acc 36.24%)
# ...

# %%
'''
PROVIDE YOUR ANSWER BELOW

For this part, I used CrossEntropyLoss because this is a multi-class classification problem with 9 gesture classes.
This loss works well since it combines softmax and log loss into one function,
so I didn’t need to manually apply softmax.

For the optimizer, I chose Adam because it usually gives good results
out of the box and adjusts the learning rate automatically, which makes
training more stable. I also added a small weight decay (1e-4) to help with regularization and to reduce overfitting.

The training code was written so that hyperparameters like learning rate,
number of epochs, weight decay, and learning rate schedule can be easily
changed. I used a StepLR scheduler to reduce the learning rate after a few epochs,
which helps the model converge better.

I also added checkpointing to save the model every few epochs and whenever it
reached the best validation accuracy, so I can always go back to the best model later if needed.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nFor this part, I used CrossEntropyLoss because this is a multi-class classification problem with 9 gesture classes. \nThis loss works well since it combines softmax and log loss into one function, \nso I didn’t need to manually apply softmax. \n\nFor the optimizer, I chose Adam because it usually gives good results \nout of the box and adjusts the learning rate automatically, which makes\ntraining more stable. I also added a small weight decay (1e-4) to help with regularization and to reduce overfitting.\n\nThe training code was written so that hyperparameters like learning rate,\nnumber of epochs, weight decay, and learning rate schedule can be easily \nchanged. I used a StepLR scheduler to reduce the learning rate after a few epochs, \nwhich helps the model converge better. \n\nI also added checkpointing to save the model every few epochs and whenever it \nreached the best validation accuracy, so I can always go back to the best model later if needed
# ...

# %% [markdown]
# ### Part (iii) “Overfit” to a Small Dataset - [1pt MODEL]
#
# One way to sanity check our neural network model and training code is to check whether the model is capable
# of “overfitting” or “memorizing” a small dataset. A properly constructed CNN with correct training code
# should be able to memorize the answers to a small number of images quickly.
#
# Construct a small dataset (e.g. just the images that you have collected). Then show that your model and
# training code is capable of memorizing the labels of this small data set.
#
# With a large batch size (e.g. the entire small dataset) and learning rate that is not too high, you should be
# able to obtain a 100% training accuracy on that small dataset relatively quickly (within 200 iterations).

# %%
# PART B.2(iii) — "OVERFIT" TO A SMALL DATASET (SANITY CHECK)
# This section created a tiny training set and showed that the model could memorize it quickly.

import torch
from torch.utils.data import Subset, DataLoader
import numpy as np

# Step 1: Built a tiny dataset from the subject-disjoint training split
# Took the first 64 samples to keep it small and mixed across classes.
small_indices = np.arange(min(64, len(train_ds)))   # train_ds came from Part 1
small_ds = Subset(train_ds, small_indices)

# Step 2: Used a full-batch loader (the entire small dataset in one batch)
small_loader = DataLoader(
    small_ds,
    batch_size=len(small_ds),   # full batch
    shuffle=True,
    num_workers=0,
    pin_memory=True
)

# Step 3: Initialized a fresh model and optimizer for the overfit test
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_overfit = GestureCNN().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_overfit.parameters(), lr=1e-3, weight_decay=0.0)  # no wd to make memorization easier

# Step 4: Trained up to 200 iterations and stopped early at 100% train accuracy
def train_overfit(model, loader, max_iters=200):
    model.train()
    it = 0
    for _ in range(max_iters):
        for x, y in loader:
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            with torch.no_grad():
                preds = logits.argmax(1)
                acc = (preds == y).float().mean().item()

            it += 1
            if it % 10 == 0 or acc == 1.0:
                print(f"Iter {it:03d} | Loss: {loss.item():.4f} | Train Acc: {acc:.2%}")
            if acc == 1.0:
                print(f"[INFO] Reached 100% training accuracy at iteration {it}.")
                return
    print("[INFO] Reached max iterations without hitting 100%.")

train_overfit(model_overfit, small_loader, max_iters=200)
# Out:
# Iter 004 | Loss: 1.4601 | Train Acc: 100.00%
# [INFO] Reached 100% training accuracy at iteration 4.

# %% [markdown]
# ## Part 3. Hyperparameter Search [7pt]
#
# ### Part (i) - [2pt EXPLORATORY]
#
# Select three hyperparameters to tune, one from each of the following categories:
#
# 1. Optimizer-related (e.g., learning rate, weight decay)
#
# 2. Architecture-related (e.g., number of filters, dropout rate, number of output channels)
#
# 3. Training Process (e.g., number of epochs, batch size)
#
# Briefly justify why you chose these three.

# %%
'''
PROVIDE YOUR ANSWER BELOW

For the hyperparameter search, I selected three hyperparameters, one from each category:

- Optimizer-related: Learning Rate
I chose the learning rate because it plays a major role in controlling how fast the model learns during training.
If the learning rate is too high, the model can overshoot minima, while a very low value can slow down learning.
I tested 0.0001, 0.0003, and 0.001 to see which one gave the best balance between stable convergence and training speed.

- Architecture-related: Dropout Rate
I tuned the dropout rate to manage overfitting by randomly dropping some neurons during training.
This helps improve generalization. I tested 0.3, 0.4, and 0.5 to find a value that regularizes the
network well without hurting performance too much.

- Training Process: Batch Size
I selected batch size because it affects both the stability of the gradients and the overall training speed.
A smaller batch size can give more stable updates but might be slower, while larger batches speed up training but
can be less stable. I tested 32, 64, and 128 to compare their impact on accuracy and efficiency.

These three hyperparameters were chosen because they are commonly tuned and have a direct influence on model performance,
convergence behavior, and generalization. By adjusting them, I could explore different training dynamics and find a
setup that worked well for this dataset and model.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nFor the hyperparameter search, I selected three hyperparameters, one from each category:\n\n- Optimizer-related: Learning Rate\nI chose the learning rate because it plays a major role in controlling how fast the model learns during training.\nIf the learning rate is too high, the model can overshoot minima, while a very low value can slow down learning.\nI tested 0.0001, 0.0003, and 0.001 to see which one gave the best balance between stable convergence and training speed.\n\n- Architecture-related: Dropout Rate\nI tuned the dropout rate to manage overfitting by randomly dropping some neurons during training.\nThis helps improve generalization. I tested 0.3, 0.4, and 0.5 to find a value that regularizes the\nnetwork well without hurting performance too much.\n\n- Training Process: Batch Size\nI selected batch size because it affects both the stability of the gradients and the overall training speed.\nA smaller batch size can give more stable updates bu
# ...

# %% [markdown]
# ### Part (ii) - [1pt MODEL]
#
# Tune the hyperparameters you listed in Part (i), trying as many values as you need to until you feel satisfied
# that you are getting a good model. Plot the training curve of at least 4 different hyperparameter settings.

# %%
# PART B.3(ii) — HYPERPARAMETER TUNING (BEGINNER-FRIENDLY VERSION)
# This code tests 4 hyperparameter settings and plots training/validation curves for comparison.

import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import time

# Defined loss function and helper for calculating accuracy
criterion = torch.nn.CrossEntropyLoss()

def acc_from_logits(logits, y):
    preds = logits.argmax(1)
    return (preds == y).float().mean().item()

# Chosen hyperparameter settings (learning rate, dropout, batch size)
configs = [
    {"lr": 0.0001, "dropout_p": 0.3, "batch_size": 32, "label": "LR=1e-4, DO=0.3, BS=32"},
    {"lr": 0.0003, "dropout_p": 0.4, "batch_size": 64, "label": "LR=3e-4, DO=0.4, BS=64"},
    {"lr": 0.0010, "dropout_p": 0.3, "batch_size": 64, "label": "LR=1e-3, DO=0.3, BS=64"},
    {"lr": 0.0003, "dropout_p": 0.5, "batch_size": 32, "label": "LR=3e-4, DO=0.5, BS=32"},
]

# Stored results for plotting later
histories = []

# Ran the same training procedure for each configuration
for cfg in configs:
    # Recreated loaders with the chosen batch size
    train_loader = DataLoader(train_ds, batch_size=cfg["batch_size"], shuffle=True, num_workers=2, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=cfg["batch_size"], shuffle=False, num_workers=2, pin_memory=True)

    # Built a new model with the chosen dropout rate
    model = GestureCNN(dropout_p=cfg["dropout_p"]).to(device)

    # Set up Adam optimizer with the chosen learning rate
    optimizer = torch.optim.Adam(model.parameters(), lr=cfg["lr"], weight_decay=1e-4)

    # Set up lists to record loss and accuracy for each epoch
    train_loss_hist, val_loss_hist = [], []
    train_acc_hist,  val_acc_hist  = [], []
    label = cfg["label"]

    # Trained for 10 epochs
    for epoch in range(1, 11):
        t0 = time.time()

        # Training phase
        model.train()
        total_loss, total_acc, total_n = 0.0, 0.0, 0
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            bs = y.size(0)
            total_loss += loss.item() * bs
            total_acc  += acc_from_logits(logits, y) * bs
            total_n    += bs

        train_loss = total_loss / total_n
        train_acc  = total_acc  / total_n

        # Validation phase
        model.eval()
        total_loss, total_acc, total_n = 0.0, 0.0, 0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                logits = model(x)
                loss = criterion(logits, y)

                bs = y.size(0)
                total_loss += loss.item() * bs
                total_acc  += acc_from_logits(logits, y) * bs
                total_n    += bs

        val_loss = total_loss / total_n
        val_acc  = total_acc  / total_n

        # Saved metrics for plotting
        train_loss_hist.append(train_loss)
        val_loss_hist.append(val_loss)
        train_acc_hist.append(train_acc)
        val_acc_hist.append(val_acc)

        # Printed results for this epoch
        dt = time.time() - t0
        print(f"{label} | Epoch {epoch:02d} | "
              f"Train {train_loss:.4f}/{train_acc:.2%} | "
              f"Val {val_loss:.4f}/{val_acc:.2%} | {dt:.1f}s")

    # Stored the history for this configuration
    histories.append({
        "label": label,
        "train_loss": train_loss_hist,
        "val_loss":   val_loss_hist,
        "train_acc":  train_acc_hist,
        "val_acc":    val_acc_hist
    })

# Plotted loss curves for all configurations
plt.figure(figsize=(10, 6))
for h in histories:
    plt.plot(h["train_loss"], label=h["label"] + " (Train)")
    plt.plot(h["val_loss"],   label=h["label"] + " (Val)")
plt.title("Training/Validation Loss — Hyperparameter Settings")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Plotted accuracy curves for all configurations
plt.figure(figsize=(10, 6))
for h in histories:
    plt.plot(h["train_acc"], label=h["label"] + " (Train)")
    plt.plot(h["val_acc"],   label=h["label"] + " (Val)")
plt.title("Training/Validation Accuracy — Hyperparameter Settings")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# LR=1e-4, DO=0.3, BS=32 | Epoch 01 | Train 2.1927/14.38% | Val 2.1924/13.23% | 4.6s
# LR=1e-4, DO=0.3, BS=32 | Epoch 02 | Train 2.1780/14.68% | Val 2.1780/16.93% | 4.8s
# LR=1e-4, DO=0.3, BS=32 | Epoch 03 | Train 2.1577/19.96% | Val 2.1645/18.78% | 4.5s
# LR=1e-4, DO=0.3, BS=32 | Epoch 04 | Train 2.1279/23.23% | Val 2.1404/18.52% | 4.3s
# LR=1e-4, DO=0.3, BS=32 | Epoch 05 | Train 2.0850/25.85% | Val 2.0969/24.87% | 5.1s
# LR=1e-4, DO=0.3, BS=32 | Epoch 06 | Train 2.0211/29.17% | Val 2.0521/25.66% | 4.2s
# LR=1e-4, DO=0.3, BS=32 | Epoch 07 | Train 1.9562/30.72% | Val 2.0432/22.49% | 4.3s
# LR=1e-4, DO=0.3, BS=32 | Epoch 08 | Train 1.9007/32.03% | Val 2.0124/19.31% | 4.8s
# LR=1e-4, DO=0.3, BS=32 | Epoch 09 | Train 1.8389/34.58% | Val 2.0836/16.40% | 4.4s
# LR=1e-4, DO=0.3, BS=32 | Epoch 10 | Train 1.7929/32.14% | Val 1.9261/28.04% | 4.3s
# LR=3e-4, DO=0.4, BS=64 | Epoch 01 | Train 2.2019/11.94% | Val 2.1996/12.43% | 5.0s
# ...

# %% [markdown]
# ### Part (iii) - [2pt DISCUSSION]
# Choose the best model out of all the ones that you have trained. Justify your choice.

# %%
'''
PROVIDE YOUR ANSWER BELOW

After training the different hyperparameter settings, the best model was the one using a learning rate of 3e-4,
dropout of 0.5, and a batch size of 32. This configuration achieved the highest and most stable validation accuracy,
reaching around 33% by the final epochs. Its validation loss curve showed a steady downward trend for most
of training, and its accuracy curve improved consistently across epochs without the sharp spikes seen
in other configurations.

In comparison, the model with a learning rate of 1e-3 showed rapid initial improvement but
exhibited unstable validation behavior mid-training, with large spikes in validation loss
and drops in accuracy. The 1e-4 learning rate configurations were stable but converged
more slowly and plateaued at lower validation accuracies. The configuration with dropout
0.4 and batch size 64 performed reasonably well, peaking around 30% validation accuracy,
but was slightly less consistent than the 0.5 dropout setting.

Overall, the 3e-4 / 0.5 / 32 configuration provided the best balance of accuracy,
regularization, and stable convergence, making it the strongest choice moving forward.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nAfter training the different hyperparameter settings, the best model was the one using a learning rate of 3e-4, \ndropout of 0.5, and a batch size of 32. This configuration achieved the highest and most stable validation accuracy, \nreaching around 33% by the final epochs. Its validation loss curve showed a steady downward trend for most \nof training, and its accuracy curve improved consistently across epochs without the sharp spikes seen\nin other configurations.\n\nIn comparison, the model with a learning rate of 1e-3 showed rapid initial improvement but\nexhibited unstable validation behavior mid-training, with large spikes in validation loss \nand drops in accuracy. The 1e-4 learning rate configurations were stable but converged \nmore slowly and plateaued at lower validation accuracies. The configuration with dropout \n0.4 and batch size 64 performed reasonably well, peaking around 30% validation accuracy, \nbut was slightly less consistent than 
# ...

# %% [markdown]
# ### Part (iv) - [2pt RESULTS]
# Report the test accuracy of your best model. You should only do this step once and prior to this step you should have only used the training and validation data.
#
# Additionally, provide a confusion matrix. Using the confusion matrix values, you must calculate and report the precision, recall, and F1-score for each letter class and report them in a table. Identify the two gestures that your model confuses most often and hypothesize why this might be the case based on their visual similarity.

# %%
# PART B.3(iv) — TEST RESULTS AND CONFUSION MATRIX

import torch
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Loaded the best model checkpoint that was saved earlier
best_model = GestureCNN(dropout_p=0.3).to(device)
ckpt = torch.load("/content/checkpoints/gesturecnn_best.pt", map_location=device)
best_model.load_state_dict(ckpt["model_state"])
best_model.eval()

# Step 2: Ran the model on the test set and stored predictions and labels
all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        logits = best_model(x)
        preds = logits.argmax(1).cpu().numpy()   # Took the predicted class
        all_preds.extend(preds)
        all_labels.extend(y.numpy())

# Step 3: Calculated the overall test accuracy
test_acc = np.mean(np.array(all_preds) == np.array(all_labels))
print(f"Test Accuracy: {test_acc:.2%}")

# Step 4: Made a confusion matrix to see which classes are being mixed up
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix — Best Model")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Step 5: Calculated precision, recall and F1-score for each class
prec, rec, f1, _ = precision_recall_fscore_support(all_labels, all_preds, zero_division=0)
num_classes = len(prec)

print("Class | Precision | Recall | F1")
for i in range(num_classes):
    print(f"{i:5d} | {prec[i]:9.2f} | {rec[i]:6.2f} | {f1[i]:5.2f}")
# Out:
# Test Accuracy: 40.16%
# Class | Precision | Recall | F1
#     0 |      0.60 |   0.29 |  0.39
#     1 |      0.40 |   0.50 |  0.44
#     2 |      0.75 |   0.71 |  0.73
#     3 |      0.69 |   0.21 |  0.33
#     4 |      0.43 |   0.32 |  0.37
#     5 |      0.21 |   0.48 |  0.29
#     6 |      0.34 |   0.74 |  0.46
#     7 |      0.56 |   0.24 |  0.33
#     8 |      0.33 |   0.08 |  0.13

# %%
'''
PROVIDE YOUR ANSWER BELOW

The best model achieved a test accuracy of 40.16%, evaluated only once on the
test set after completing all training and validation. The confusion matrix
above shows how predictions are distributed across the nine gesture classes (A–I).

From the confusion matrix, I computed precision, recall, and F1-scores for each class. Some classes performed notably well,
such as Class 2 (C) with a precision of 0.75 and recall of 0.71, and Class 6 (G) with a recall of 0.74. In contrast, classes
like Class 8 (I) had very low recall (0.08), indicating that the model struggled to correctly identify those gestures.
Class 5 (F) also showed low precision (0.21) and moderate recall (0.48), suggesting frequent misclassifications.

The two gestures that were most often confused were Class 6 (G) and Class 7 (H). This is visible in the confusion
matrix, where a noticeable number of true G samples were predicted as H, and vice versa. This confusion is
reasonable because the G and H gestures are visually similar in shape and orientation, making them harder
to distinguish, especially given the subject-disjoint split and the relatively small dataset.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nThe best model achieved a test accuracy of 40.16%, evaluated only once on the \ntest set after completing all training and validation. The confusion matrix \nabove shows how predictions are distributed across the nine gesture classes (A–I).\n\nFrom the confusion matrix, I computed precision, recall, and F1-scores for each class. Some classes performed notably well, \nsuch as Class 2 (C) with a precision of 0.75 and recall of 0.71, and Class 6 (G) with a recall of 0.74. In contrast, classes \nlike Class 8 (I) had very low recall (0.08), indicating that the model struggled to correctly identify those gestures. \nClass 5 (F) also showed low precision (0.21) and moderate recall (0.48), suggesting frequent misclassifications.\n\nThe two gestures that were most often confused were Class 6 (G) and Class 7 (H). This is visible in the confusion \nmatrix, where a noticeable number of true G samples were predicted as H, and vice versa. This confusion is \nreasona
# ...

# %% [markdown]
# ## Part 4. Transfer Learning [8pt]
# For many image classification tasks, it is generally not a good idea to train a very large deep neural network
# model from scratch due to the enormous compute requirements and lack of sufficient amounts of training
# data.
#
# One of the better options is to try using an existing model that performs a similar task to the one you need
# to solve. This method of utilizing a pre-trained network for other similar tasks is broadly termed **Transfer
# Learning**. In this assignment, we will use Transfer Learning to extract features from the hand gesture
# images. Then, train a smaller network to use these features as input and classify the hand gestures.
#
# As you have learned from the CNN lecture, convolution layers extract various features from the images which
# get utilized by the fully connected layers for correct classification. AlexNet architecture played a pivotal
# role in establishing Deep Neural Nets as a go-to tool for image classification problems and we will use an
# ImageNet pre-trained AlexNet model to extract features in this assignment.

# %% [markdown]
# ### Part (i) - [2pt EXPLORATORY]
# Here is the code to load the AlexNet network, with pretrained weights. When you first run the code, PyTorch
# will download the pretrained weights from the internet.

# %%
import torchvision.models
alexnet = torchvision.models.alexnet(pretrained=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 197MB/s]

# %% [markdown]
# The alexnet model is split up into two components: *alexnet.features* and *alexnet.classifier*. The
# first neural network component, *alexnet.features*, is used to compute convolutional features, which are
# taken as input in *alexnet.classifier*.
#
# The neural network alexnet.features expects an image tensor of shape Nx3x224x224 as input and it will
# output a tensor of shape Nx256x6x6 . (N = batch size).
#
# Compute the AlexNet features for each of your training, validation, and test data. Here is an example code
# snippet showing how you can compute the AlexNet features for some images (your actual code might be
# different):

# %%
# PART B.4(i) — ALEXNET FEATURE EXTRACTION (FINAL)

# STEP 1: IMPORTS
import os, torch
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader
from pathlib import Path

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# STEP 2: LOADED ALEXNET AND KEPT ONLY CONV FEATURES
alexnet = models.alexnet(weights=models.AlexNet_Weights.IMAGENET1K_V1).to(device)
alexnet.eval()
feat = alexnet.features

# STEP 3: USED IMAGENET NORMALIZATION (ALEXNET WAS TRAINED WITH THIS)
imgnet_tfms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225]),
])

# STEP 4: CHECKED IF TRAIN/VAL/TEST LOADERS ALREADY EXISTED
def loaders_exist():
    return all(name in globals() for name in ["train_loader", "val_loader", "test_loader"])

# STEP 5: FOUND THE DATA FOLDER WHEN LOADERS WERE MISSING
def find_data_root():
    # TRIED COMMON NAMES FIRST
    candidates = [
        "/content/Processed_Lab_3b_Gesture_Dataset_Revised",
        "/content/Processed_Lab_3b_Gesture_Dataset Revised",
        "/content/Lab_3b_Gesture_Dataset_Revised",
        "/content/Lab_3b_Gesture_Dataset Revised",
        "/content/Gesture_Dataset",
        "/content/gesture_data",
    ]
    for root in candidates:
        if os.path.isdir(root):
            has_train = os.path.isdir(os.path.join(root, "train"))
            has_val   = os.path.isdir(os.path.join(root, "val")) or os.path.isdir(os.path.join(root, "valid"))
            has_test  = os.path.isdir(os.path.join(root, "test"))
            if has_train and has_val and has_test:
                return root
    # LAST RESORT: SCANNED /CONTENT
    for root, dirs, _ in os.walk("/content"):
        d = set(n.lower() for n in dirs)
        if "train" in d and ("val" in d or "valid" in d) and "test" in d:
            return root
    return None

# STEP 6: BUILT DATALOADERS IF NOT ALREADY AVAILABLE
if not loaders_exist():
    DATA_ROOT = find_data_root()
    if DATA_ROOT is None:
        print("[ERROR] DID NOT FIND train/val(or valid)/test FOLDER UNDER /content")
        os.system("ls -lah /content")
        raise SystemExit

    TRAIN_DIR = os.path.join(DATA_ROOT, "train")
    VAL_DIR   = os.path.join(DATA_ROOT, "val") if os.path.isdir(os.path.join(DATA_ROOT, "val")) else os.path.join(DATA_ROOT, "valid")
    TEST_DIR  = os.path.join(DATA_ROOT, "test")

    train_ds = datasets.ImageFolder(TRAIN_DIR, transform=imgnet_tfms)
    val_ds   = datasets.ImageFolder(VAL_DIR,   transform=imgnet_tfms)
    test_ds  = datasets.ImageFolder(TEST_DIR,  transform=imgnet_tfms)

    train_loader = DataLoader(train_ds, batch_size=64, shuffle=False, num_workers=2, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=64, shuffle=False, num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_ds,  batch_size=64, shuffle=False, num_workers=2, pin_memory=True)

# STEP 7: RAN ONE BATCH THROUGH ALEXNET.FEATURES TO SHOW SHAPE
xb, _ = next(iter(train_loader))
with torch.no_grad():
    fb = feat(xb.to(device))                  # [N, 256, 6, 6]
print("Feature batch shape:", tuple(fb.shape))

# STEP 8: EXTRACTED AND SAVED FEATURES ONCE FOR EACH SPLIT
@torch.no_grad()
def extract_and_save(loader, out_path: Path):
    alexnet.eval()
    feats, labels = [], []
    for x, y in loader:
        f = feat(x.to(device)).cpu()          # [B, 256, 6, 6]
        feats.append(f)
        labels.append(y.clone())
    feats  = torch.cat(feats, dim=0)          # [TOTAL, 256, 6, 6]
    labels = torch.cat(labels, dim=0)         # [TOTAL]
    torch.save({"features": feats, "labels": labels}, out_path)

OUT_DIR = Path("/content/alexnet_features")
OUT_DIR.mkdir(parents=True, exist_ok=True)

extract_and_save(train_loader, OUT_DIR / "train_features.pt")
extract_and_save(val_loader,   OUT_DIR / "val_features.pt")
extract_and_save(test_loader,  OUT_DIR / "test_features.pt")

print("Saved:", OUT_DIR / "train_features.pt")
print("Saved:", OUT_DIR / "val_features.pt")
print("Saved:", OUT_DIR / "test_features.pt")
# Out:
# Feature batch shape: (32, 256, 6, 6)
# Saved: /content/alexnet_features/train_features.pt
# Saved: /content/alexnet_features/val_features.pt
# Saved: /content/alexnet_features/test_features.pt

# %% [markdown]
# **Save the computed features**. You will be using these features as input to your neural network in Part
# (ii), and you do not want to re-compute the features every time. Instead, run *alexnet.features* once for
# each image, and save the result.

# %%
# Already implemented feature extraction and saving in previous cell.

# %% [markdown]
# ### Part (ii) - [2pt MODEL]
# Build a new classifier to attach to the AlexNet feature extractor. Your model must use the following sequence of layers:
#
# AlexNet feature → Flatten → Linear → ReLU → Dropout → Linear
#
# Use a dropout probability of 20%; this value can be tuned in the next part. Justify your choice of the Linear layer sizes.
#
# Here is an example of how your model may be called:

# %%
# features = ... load precomputed alexnet.features(img) ...
output = model(features)
prob = F.softmax(output)

# %%
# STEP 1: import modules we need
import torch
import torch.nn as nn
import torch.nn.functional as F

# STEP 2: define classifier model that takes AlexNet features as input
# AlexNet feature shape: [N, 256, 6, 6] → flatten to 256*6*6 = 9216
# layer structure: Flatten → Linear → ReLU → Dropout → Linear
class GestureClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(256 * 6 * 6, 512)   # first linear layer
        self.relu = nn.ReLU()
        self.drop = nn.Dropout(0.2)              # 20% dropout probability
        self.fc2 = nn.Linear(512, 9)             # final layer → 9 classes (A–I)

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.fc2(x)
        return x

# STEP 3: create model instance
model = GestureClassifier()

# %%
'''
PROVIDE YOUR ANSWER BELOW

I chose 512 units for the first Linear layer to reduce the 9216-dimensional flattened feature vector (256×6×6) to
a more manageable size while still keeping enough capacity to learn useful patterns. This makes the model less
computationally heavy and helps prevent overfitting. The final Linear layer has 9 outputs, one for each of the
gesture classes (A–I), which matches the classification task.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nI chose 512 units for the first Linear layer to reduce the 9216-dimensional flattened feature vector (256×6×6) to\na more manageable size while still keeping enough capacity to learn useful patterns. This makes the model less\ncomputationally heavy and helps prevent overfitting. The final Linear layer has 9 outputs, one for each of the\ngesture classes (A–I), which matches the classification task.\n\n'

# %% [markdown]
# ### Part (iii) - [1pt MODEL]
# Train your new network, including any hyperparameter tuning. Plot and submit the training curve of your
# best model only.
#
# Note: Depending on how you are caching (saving) your AlexNet features, PyTorch might still be tracking
# updates to the **AlexNet weights**, which we are not tuning. One workaround is to convert your AlexNet
# feature tensor into a numpy array, and then back into a PyTorch tensor.

# %%
tensor = torch.from_numpy(tensor.detach().numpy())

# %%
# PART B.4(iii) — TRAINING THE SMALL CLASSIFIER ON PRECOMPUTED ALEXNET FEATURES

# STEP 1: imported modules that were needed
import torch, math
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

# STEP 2: loaded the precomputed feature files saved in Part 4(i)
train_blob = torch.load("/content/alexnet_features/train_features.pt", map_location="cpu")
val_blob   = torch.load("/content/alexnet_features/val_features.pt",   map_location="cpu")

X_train, y_train = train_blob["features"].float(), train_blob["labels"].long()
X_val,   y_val   = val_blob["features"].float(),   val_blob["labels"].long()

# STEP 3: built TensorDatasets + DataLoaders (only the classifier was trained)
batch_size = 64
train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(TensorDataset(X_val,   y_val),   batch_size=batch_size, shuffle=False)

# STEP 4: created the classifier and moved it to device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# if the model class was not in memory, defined it quickly (same as Part 4(ii))
try:
    GestureClassifier
except NameError:
    class GestureClassifier(nn.Module):
        def __init__(self):
            super().__init__()
            self.flatten = nn.Flatten()
            self.fc1 = nn.Linear(256 * 6 * 6, 512)
            self.relu = nn.ReLU()
            self.drop = nn.Dropout(0.2)
            self.fc2 = nn.Linear(512, 9)
        def forward(self, x):
            x = self.flatten(x)
            x = self.fc1(x)
            x = self.relu(x)
            x = self.drop(x)
            x = self.fc2(x)
            return x

model = GestureClassifier().to(device)

# STEP 5: set loss + optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)

# STEP 6: trained for a few epochs and tracked loss/accuracy
epochs = 12
hist = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

def accuracy_from_logits(logits, targets):
    preds = logits.argmax(1)
    return (preds == targets).float().mean().item()

for ep in range(1, epochs + 1):
    # training
    model.train()
    tloss, tcorrect, tcount = 0.0, 0, 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)

        optimizer.zero_grad()
        out = model(xb)
        loss = criterion(out, yb)
        loss.backward()
        optimizer.step()

        tloss += loss.item() * yb.size(0)
        tcorrect += (out.argmax(1) == yb).sum().item()
        tcount += yb.size(0)

    train_loss = tloss / tcount
    train_acc  = tcorrect / tcount

    # validation
    model.eval()
    with torch.no_grad():
        vloss, vcorrect, vcount = 0.0, 0, 0
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            out = model(xb)
            loss = criterion(out, yb)
            vloss += loss.item() * yb.size(0)
            vcorrect += (out.argmax(1) == yb).sum().item()
            vcount += yb.size(0)

    val_loss = vloss / vcount
    val_acc  = vcorrect / vcount

    hist["train_loss"].append(train_loss)
    hist["val_loss"].append(val_loss)
    hist["train_acc"].append(train_acc)
    hist["val_acc"].append(val_acc)

    print(f"Epoch {ep:02d} | Train {train_loss:.4f}/{train_acc*100:.2f}% | "
          f"Val {val_loss:.4f}/{val_acc*100:.2f}%")

# STEP 7: plotted the training curves for the report
plt.figure(figsize=(11,4))
plt.subplot(1,2,1)
plt.plot(hist["train_loss"], label="Train")
plt.plot(hist["val_loss"],   label="Val")
plt.title("Loss")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()

plt.subplot(1,2,2)
plt.plot(hist["train_acc"], label="Train")
plt.plot(hist["val_acc"],   label="Val")
plt.title("Accuracy")
plt.xlabel("Epoch"); plt.ylabel("Accuracy"); plt.legend()
plt.show()

# Create folder if it doesn't exist
os.makedirs("/content/alexnet_features", exist_ok=True)

# Save the trained transfer head model
torch.save({"model_state": model.state_dict()}, "/content/alexnet_features/gesture_classifier.pt")
# Out:
# Epoch 01 | Train 0.9878/69.34% | Val 0.8695/78.31%
# Epoch 02 | Train 0.2050/94.59% | Val 0.7726/80.95%
# Epoch 03 | Train 0.1190/95.96% | Val 0.7173/80.42%
# Epoch 04 | Train 0.0491/99.11% | Val 0.7673/82.01%
# Epoch 05 | Train 0.0253/99.88% | Val 0.7376/80.95%
# Epoch 06 | Train 0.0158/99.94% | Val 0.7633/82.54%
# Epoch 07 | Train 0.0094/100.00% | Val 0.7684/82.54%
# Epoch 08 | Train 0.0077/100.00% | Val 0.7669/82.80%
# Epoch 09 | Train 0.0060/100.00% | Val 0.7976/82.28%
# Epoch 10 | Train 0.0051/100.00% | Val 0.8207/82.28%
# Epoch 11 | Train 0.0047/100.00% | Val 0.8021/82.80%
# Epoch 12 | Train 0.0041/100.00% | Val 0.8102/82.80%

# %% [markdown]
# ### Part (iv) - [2pt RESULTS]
# Report the test accuracy of your best model. How does the test accuracy compare to Part 3(iv) without transfer learning?

# %%
# PART B.4(iv) — TEST SET RESULT FOR TRANSFER LEARNING

# Step 1: Imported everything needed for evaluation
import os, torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Step 2: Loaded the precomputed test features that were saved earlier in Part 4(i)
test_blob = torch.load("/content/alexnet_features/test_features.pt", map_location="cpu")
X_test, y_test = test_blob["features"].float(), test_blob["labels"].long()
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=128, shuffle=False)

# Step 3: Reused the same classifier model from Part 4(ii), or defined it again if needed
try:
    GestureClassifier
except NameError:
    class GestureClassifier(nn.Module):
        def __init__(self):
            super().__init__()
            self.flatten = nn.Flatten()
            self.fc1 = nn.Linear(256 * 6 * 6, 512)
            self.relu = nn.ReLU()
            self.drop = nn.Dropout(0.2)
            self.fc2 = nn.Linear(512, 9)
        def forward(self, x):
            x = self.flatten(x)
            x = self.fc1(x)
            x = self.relu(x)
            x = self.drop(x)
            x = self.fc2(x)
            return x

# If the trained model is still in memory, I used that. Otherwise, I loaded it from a saved checkpoint.
if "model" in globals():
    clf = model
else:
    clf = GestureClassifier().to(device)
    ckpt_path = "/content/alexnet_features/gesture_classifier.pt"
    if os.path.exists(ckpt_path):
        clf.load_state_dict(torch.load(ckpt_path, map_location=device))
    clf.eval()

# Step 4: Evaluated the model on the test set to get the final accuracy and loss
clf.eval()
criterion = nn.CrossEntropyLoss()
total, correct, loss_sum = 0, 0, 0.0

with torch.no_grad():
    for xb, yb in test_loader:
        xb, yb = xb.to(device), yb.to(device)
        logits = clf(xb)
        loss_sum += criterion(logits, yb).item() * yb.size(0)
        preds = logits.argmax(1)
        correct += (preds == yb).sum().item()
        total += yb.size(0)

test_loss = loss_sum / total
test_acc  = correct / total

# Step 5: Compared the test accuracy here with the one from Part 3(iv) without transfer learning
prev_no_tl_acc = 0.4043  # from Part 3(iv)
improve = (test_acc - prev_no_tl_acc) * 100

# Step 6: Printed results
print("Final Test Results (Transfer Learning)")
print(f"  Test Loss: {test_loss:.4f}")
print(f"  Test Accuracy: {test_acc*100:.2f}%")

print("\nComparison with Part 3(iv) (no transfer)")
print(f"  Improvement: {improve:.2f} percentage points")
# Out:
# Final Test Results (Transfer Learning)
#   Test Loss: 0.3907
#   Test Accuracy: 86.79%
#
# Comparison with Part 3(iv) (no transfer)
#   Improvement: 46.36 percentage points

# %%
'''
PROVIDE YOUR ANSWER BELOW

The best model achieved a test accuracy of 86.79% with transfer learning.
This is a +46.36 percentage point improvement compared to Part 3(iv),
where the model trained from scratch reached about 40.43% accuracy.
This large increase shows the benefit of using AlexNet’s pretrained features,
which already capture useful visual patterns. Instead of learning everything
from scratch with limited data, the classifier only had to learn how to map
these high-level features to the 9 gesture classes, resulting in much better generalization.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nThe best model achieved a test accuracy of 86.79% with transfer learning.\nThis is a +46.36 percentage point improvement compared to Part 3(iv),\nwhere the model trained from scratch reached about 40.43% accuracy.\nThis large increase shows the benefit of using AlexNet’s pretrained features,\nwhich already capture useful visual patterns. Instead of learning everything\nfrom scratch with limited data, the classifier only had to learn how to map\nthese high-level features to the 9 gesture classes, resulting in much better generalization.\n\n'

# %% [markdown]
# ## Part 5. Testing on New Data [14pt]
# As a final step in testing we will be revisiting the sample images that you had collected and submitted with your assignment. These sample images should be untouched and will be used to demonstrate how well your model works at identifying your hand guestures.

# %% [markdown]
# ### Part (i) - [2pt EXPLORATORY]
# Load and process the hand gesture images you had collected so that they can easily be evaulated by your model.

# %%
# PART B.5(i) — LOADING AND PROCESSING MY HAND GESTURE IMAGES
# This cell unzips my images, sorts them into A..I folders, builds two loaders (TL + baseline),
# and shows a quick thumbnail grid for sanity checking.

# STEP 1: imports
import os, zipfile, re, shutil
from pathlib import Path
import numpy as np
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# STEP 2: set paths (update ZIP_PATH if the filename differs in Colab)
ZIP_PATH  = Path("/content/Yadav_1008289870.zip")    # uploaded on the left panel
DEST_ROOT = Path("/content/my_hand_samples")         # will contain class subfolders A..I
assert ZIP_PATH.exists(), f"ZIP not found: {ZIP_PATH}"

# STEP 3: clean output folder and unzip to a temp directory
if DEST_ROOT.exists():
    shutil.rmtree(DEST_ROOT)
for cls in "ABCDEFGHI":
    (DEST_ROOT/cls).mkdir(parents=True, exist_ok=True)

tmp_extract = Path("/content/_tmp_myhands_unzip")
if tmp_extract.exists():
    shutil.rmtree(tmp_extract)
tmp_extract.mkdir(parents=True, exist_ok=True)
with zipfile.ZipFile(ZIP_PATH, "r") as zf:
    zf.extractall(tmp_extract)

# STEP 4: move files into A..I based on filename pattern: ..._<LETTER>_#.jpg
img_exts = {".jpg", ".jpeg", ".png", ".JPG", ".JPEG", ".PNG"}
pat = re.compile(r".*?_([A-Ia-i])_[0-9]+(?:\.[A-Za-z]+)?$")  # capture the letter between underscores
moved = 0
for p in tmp_extract.rglob("*"):
    if p.is_file() and p.suffix in img_exts:
        letter = None
        m = pat.match(p.name)
        if m:
            letter = m.group(1).upper()
        else:
            # fallback: look for a single A..I token in the stem
            for tok in re.split(r"[_\-\s\.]", p.stem):
                if len(tok) == 1 and tok.upper() in "ABCDEFGHI":
                    letter = tok.upper()
                    break
        if letter is None:
            continue
        shutil.copy2(p, DEST_ROOT/letter/p.name)
        moved += 1

# STEP 5: tiny dataset (no torchvision). option to apply ImageNet normalization for AlexNet.
IMAGENET_MEAN = np.array([0.485, 0.456, 0.406], dtype=np.float32)
IMAGENET_STD  = np.array([0.229, 0.224, 0.225], dtype=np.float32)

class HandImageDataset(Dataset):
    def __init__(self, root_dir: Path, imagenet_norm: bool, size: int = 224):
        self.root_dir = Path(root_dir)
        self.classes = sorted([d.name for d in self.root_dir.iterdir() if d.is_dir()])
        self.class_to_idx = {c:i for i,c in enumerate(self.classes)}
        self.samples = []
        for c in self.classes:
            for f in sorted((self.root_dir/c).iterdir()):
                if f.is_file() and f.suffix.lower() in (".jpg",".jpeg",".png"):
                    self.samples.append((f, self.class_to_idx[c]))
        self.size = size
        self.imagenet_norm = imagenet_norm

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        fp, label = self.samples[idx]
        img = Image.open(fp).convert("RGB").resize((self.size, self.size), Image.Resampling.BILINEAR)
        arr = np.asarray(img).astype(np.float32) / 255.0   # H,W,C in [0,1]
        if self.imagenet_norm:
            arr = (arr - IMAGENET_MEAN) / IMAGENET_STD     # apply ImageNet normalization
        arr = np.transpose(arr, (2,0,1))                   # to CHW
        return torch.from_numpy(arr), label, str(fp)

# STEP 6: datasets + dataloaders
# transfer-learning path (AlexNet): use ImageNet normalization
sample_ds_tl  = HandImageDataset(DEST_ROOT, imagenet_norm=True,  size=224)
# baseline CNN path (match my baseline preprocessing = resize+ToTensor)
sample_ds_raw = HandImageDataset(DEST_ROOT, imagenet_norm=False, size=224)

# one-shot loaders (all 27 at once)
sample_loader_tl  = DataLoader(sample_ds_tl,  batch_size=len(sample_ds_tl), shuffle=False)
sample_loader_raw = DataLoader(sample_ds_raw, batch_size=len(sample_ds_raw), shuffle=False)

# STEP 7: quick summary
counts = {c:0 for c in sample_ds_tl.classes}
for _, lbl, _ in sample_ds_tl:
    counts[sample_ds_tl.classes[lbl]] += 1
print("[INFO] Organized:", DEST_ROOT)
print("[INFO] Classes:", sample_ds_tl.classes)
print("[INFO] Total images:", len(sample_ds_tl))
print("[INFO] Per-class counts:", counts)

# STEP 8: thumbnail grid (inverse-normalized for display)
def denorm_imgnet(t):
    t = t.numpy()
    t = np.transpose(t, (1,2,0))
    t = t * IMAGENET_STD + IMAGENET_MEAN
    return np.clip(t, 0, 1)

imgs, labels, paths = next(iter(sample_loader_tl))
n, cols = imgs.shape[0], 9
rows = (n + cols - 1)//cols
plt.figure(figsize=(cols*1.6, rows*1.6))
for i in range(n):
    ax = plt.subplot(rows, cols, i+1)
    ax.imshow(denorm_imgnet(imgs[i]))
    ax.set_title(sample_ds_tl.classes[labels[i]], fontsize=8)
    ax.axis("off")
plt.tight_layout(); plt.show()
# Out:
# [INFO] Organized: /content/my_hand_samples
# [INFO] Classes: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# [INFO] Total images: 27
# [INFO] Per-class counts: {'A': 3, 'B': 3, 'C': 3, 'D': 3, 'E': 3, 'F': 3, 'G': 3, 'H': 3, 'I': 3}

# %% [markdown]
# ### Part (ii) - [5pt RESULTS]
# Using the best transfer learning model developed in Part 4. Report the test accuracy on your sample images and how it compares to the test accuracy obtained in Part 4(iv)? Also, use your best model from Part 3 to report the test accuracy on the new sample images and how it compares to the test accuracy obtained in Part 3(iv). You should present your results in a pandas DataFrame.
#
# This question will also be evaluated on the overal performance achieved.

# %%
# PART B.5(ii) — RESULTS TABLE + SANITY CHECK (PER-IMAGE)
# Goal: evaluated the best transfer-learning model and the best baseline CNN on my 27 images,
#       then compared each result to the earlier test accuracy from Part 4(iv) and Part 3(iv).

# STEP 1: imported modules and set device
import torch, pandas as pd
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from pathlib import Path
from IPython.display import display, Markdown

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
assert "sample_loader_tl" in globals() and "sample_loader_raw" in globals(), "Run Part 5(i) first."

# STEP 2: defined models (same as earlier) so this cell remained self-contained
class GestureCNN(nn.Module):
    def __init__(self, dropout_p: float = 0.4):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1); self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1); self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1); self.bn3 = nn.BatchNorm2d(128)
        self.pool  = nn.MaxPool2d(2, 2)
        self.gap   = nn.AdaptiveAvgPool2d(1)
        self.fc1   = nn.Linear(128, 128)
        self.drop  = nn.Dropout(dropout_p)
        self.fc2   = nn.Linear(128, 9)
    def forward(self, x):
        x = self.pool(torch.relu(self.bn1(self.conv1(x))))
        x = self.pool(torch.relu(self.bn2(self.conv2(x))))
        x = self.pool(torch.relu(self.bn3(self.conv3(x))))
        x = self.gap(x).flatten(1)
        x = torch.relu(self.fc1(x)); x = self.drop(x)
        return self.fc2(x)

class GestureClassifier(nn.Module):
    # Transfer head used with alexnet.features: Flatten → Linear → ReLU → Dropout → Linear
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(256 * 6 * 6, 512)
        self.relu = nn.ReLU()
        self.drop = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 9)
    def forward(self, x):
        x = self.flatten(x); x = self.fc1(x); x = self.relu(x); x = self.drop(x)
        return self.fc2(x)

# STEP 3: loaded trained weights from Parts 3 and 4
baseline_ckpt_path = "/content/checkpoints/gesturecnn_best.pt"
transfer_head_ckpt = "/content/alexnet_features/gesture_classifier.pt"

baseline = GestureCNN(dropout_p=0.4).to(device).eval()
baseline.load_state_dict(torch.load(baseline_ckpt_path, map_location=device)["model_state"])

head = GestureClassifier().to(device).eval()
head.load_state_dict(torch.load(transfer_head_ckpt, map_location=device)["model_state"])

alexnet = models.alexnet(weights=models.AlexNet_Weights.IMAGENET1K_V1).to(device).eval()
feat = alexnet.features

# STEP 4: defined helpers that computed accuracy for each model
@torch.no_grad()
def accuracy_from_loader_logits(model, loader):
    correct, total = 0, 0
    for xb, yb, _ in loader:
        xb, yb = xb.to(device), yb.to(device)
        logits = model(xb)
        correct += (logits.argmax(1) == yb).sum().item()
        total   += yb.size(0)
    return correct / max(1, total)

@torch.no_grad()
def accuracy_transfer(loader_tl, feature_block, head):
    correct, total = 0, 0
    for xb, yb, _ in loader_tl:
        xb, yb = xb.to(device), yb.to(device)
        logits = head(feature_block(xb))
        correct += (logits.argmax(1) == yb).sum().item()
        total   += yb.size(0)
    return correct / max(1, total)

# STEP 5: computed accuracies on my 27 images
new_acc_transfer = accuracy_transfer(sample_loader_tl, feat, head)
new_acc_baseline = accuracy_from_loader_logits(baseline, sample_loader_raw)

# STEP 6: recalled the earlier test accuracies (from Part 4(iv) and Part 3(iv))
ref_test_transfer = 0.8679
ref_test_baseline = 0.4016

# STEP 7: built the results table that compared new-image accuracy to earlier test accuracy
df_results = pd.DataFrame({
    "model": ["transfer_alexnet_head", "baseline_cnn"],
    "test_accuracy_from_part_4iv_or_3iv": [ref_test_transfer, ref_test_baseline],
    "accuracy_on_my_27_images": [new_acc_transfer, new_acc_baseline],
    # reported the simple difference in percentage points (new − reference)
    "difference_in_percentage_points": [
        (new_acc_transfer - ref_test_transfer) * 100,
        (new_acc_baseline - ref_test_baseline) * 100
    ],
})

# STEP 8: displayed the results with percentage formatting
display(Markdown("### Part 5(ii) — Accuracy on My 27 Images (compared to earlier test accuracy)"))
display(
    df_results.style.format({
        "test_accuracy_from_part_4iv_or_3iv": "{:.2%}",
        "accuracy_on_my_27_images": "{:.2%}",
        "difference_in_percentage_points": "{:.2f}"
    })
)

# SANITY CHECK for myself
# Purpose: listed each file with its true label, each model's prediction, and its confidence.

# STEP 9: prepared class names and collected baseline predictions keyed by filename
class_names = sample_loader_tl.dataset.classes

baseline_map = {}
with torch.no_grad():
    for xb, yb, paths in sample_loader_raw:
        xb = xb.to(device)
        probs = F.softmax(baseline(xb), dim=1)
        preds = probs.argmax(1).cpu()
        for i, p in enumerate(paths):
            fname = Path(p).name
            baseline_map[fname] = (
                class_names[preds[i].item()],
                float(probs[i, preds[i]].item())
            )

# STEP 10: built per-image rows from the transfer path and attached baseline outputs
rows = []
with torch.no_grad():
    for xb, yb, paths in sample_loader_tl:
        xb = xb.to(device)
        probs = F.softmax(head(feat(xb)), dim=1)
        preds = probs.argmax(1).cpu()
        yb = yb.cpu()
        for i, p in enumerate(paths):
            fname = Path(p).name
            b_pred, b_prob = baseline_map.get(fname, (None, None))
            rows.append({
                "file_name": fname,
                "true_label": class_names[yb[i].item()],
                "transfer_prediction": class_names[preds[i].item()],
                "transfer_top1_probability": float(probs[i, preds[i]].item()),
                "baseline_prediction": b_pred,
                "baseline_top1_probability": b_prob,
            })

df_sanity = pd.DataFrame(rows)
df_sanity["transfer_correct"] = (df_sanity["true_label"] == df_sanity["transfer_prediction"])
df_sanity["baseline_correct"]  = (df_sanity["true_label"] == df_sanity["baseline_prediction"])
df_sanity = df_sanity.sort_values(
    ["transfer_correct","baseline_correct","true_label","file_name"],
    ascending=[True, True, True, True]
).reset_index(drop=True)

# STEP 11: displayed the sanity-check table
display(Markdown("### Sanity Check — Per-Image Predictions on My 27 Images (not graded)"))
display(df_sanity)
# Out:
# ### Part 5(ii) — Accuracy on My 27 Images (compared to earlier test accuracy)
# <style type="text/css">
# </style>
# <table id="T_b41b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b41b6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_b41b6_level0_col1" class="col_heading level0 col1" >test_accuracy_from_part_4iv_or_3iv</th>
#       <th id="T_b41b6_level0_col2" class="col_heading level0 col2" >accuracy_on_my_27_images</th>
#       <th id="T_b41b6_level0_col3" class="col_heading level0 col3" >difference_in_percentage_points</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b41b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b41b6_row0_col0" class="data row0 col0" >transfer_alexnet_head</td>
#       <td id="T_b41b6_row0_col1" class="data row0 col1" >86.79%</td>
#       <td id="T_b41b6_row0_col2" class="data row0 col2" >100.00%</td>
# ...

# %% [markdown]
# ### Part (iii) - [5pt DISCUSSION]
# How well did your models do for the different hand guestures? Provide an explanation for why you think your models performed the way it did? Be sure to compare the results of training, validation, testing, and also on the new data represented by your own hand gestures.
#
# How well would this model perform if you were to deploy it in the real-world? List some things you could do to improve the model performance.

# %%
'''
PROVIDE YOUR ANSWER BELOW

The baseline CNN that I trained from scratch improved during training but leveled off at about
36% validation accuracy and 40.16% test accuracy. From the confusion matrix in Part 3, it handled clearer
shapes like C fairly well (best F1 around 0.73), but it struggled on H and I, which had low recall. Common
mistakes were between G and H and between F and B or E. These errors make sense because those letters have
similar silhouettes when the hand is slightly rotated or when the thumb and finger spacing are not obvious.

The transfer learning model that uses alexnet.features with a small classifier head performed much better
across all splits. Training accuracy reached near 100%, validation stabilized around 82%, and the
final test accuracy was 86.79%. On my 27 new images, the model reached 100%. The gain over the baseline
is expected because the pretrained features already capture basic visual patterns, so the classifier only
has to learn the mapping to the nine letters. My photos also followed the data collection rules closely,
with a white background, centered hand, and good lighting, which matched the preprocessing used during training and validation.

Comparing across splits, the baseline showed a clear gap from training to validation and test, which suggests
it did not generalize well to new subjects. The transfer model held up better from validation to test
and then performed best on my new photos, which were clean and consistent with the training conditions.
Per class, the largest improvements with transfer were on pairs that previously overlapped in shape,
such as G and H, and on letters that rely on small details, like F.

In a real deployment, I would expect strong performance in controlled conditions: a single hand, adequate
lighting, a simple background, and a camera distance similar to the dataset. Accuracy would likely drop
with cluttered backgrounds, low light or shadows, left-hand mirroring, large rotations, unusual scales,
partial occlusion, or motion blur.

To improve robustness, I would expand the dataset to include more subjects, skin tones, hand sizes,
sleeves and accessories, camera types, and environments, and keep the classes balanced. I would apply
stronger augmentation, including rotation, translation, scale changes, color jitter, slight blur or noise,
and varied backgrounds. I would add a hand detection or segmentation step to standardize
the crop and scale before classification. I would consider light fine tuning of the last AlexNet
block while freezing earlier layers and also compare with compact backbones like ResNet-18 or MobileNetV3.
For deployment, I would calibrate the predicted probabilities and add a simple low-confidence rule
that asks for another photo. Overall, the transfer approach clearly outperformed the baseline on
validation, test, and my new images, and with these changes it should be suitable for use beyond the classroom setting.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nThe baseline CNN that I trained from scratch improved during training but leveled off at about \n36% validation accuracy and 40.16% test accuracy. From the confusion matrix in Part 3, it handled clearer \nshapes like C fairly well (best F1 around 0.73), but it struggled on H and I, which had low recall. Common \nmistakes were between G and H and between F and B or E. These errors make sense because those letters have \nsimilar silhouettes when the hand is slightly rotated or when the thumb and finger spacing are not obvious.\n\nThe transfer learning model that uses alexnet.features with a small classifier head performed much better\nacross all splits. Training accuracy reached near 100%, validation stabilized around 82%, and the \nfinal test accuracy was 86.79%. On my 27 new images, the model reached 100%. The gain over the baseline \nis expected because the pretrained features already capture basic visual patterns, so the classifier only \nhas to lear
# ...

# %% [markdown]
# ### Part (iv) - [2pt DISCUSSION]
# Reflect on the ethical implications of deploying a hand gesture recognition model in real-world applications. What are some potential biases that could arise in your model, and how might they impact different user groups?
#
# Discuss measures you can take to identify and mitigate these biases during the development and deployment phases. Consider aspects such as data collection, model training, and user feedback.

# %%
'''
PROVIDE YOUR ANSWER BELOW

If this model were used in the real world, the main risk I see is uneven performance across different users.
Bias could appear because of skin tone, hand size, age, left versus right hand, tattoos or jewelry, sleeves that
cover part of the hand, and differences in lighting and background. If the training data leans toward clean,
well lit, centered, right hand photos from a small set of subjects, the system can look good on paper but fail
more often for people and environments it did not see. That creates unequal error rates across groups, which is unfair
and can block communication in situations where people need the model to work.

Bias can enter at several points. During data collection it is easy to oversample ideal images and undersample real world variety.
During training the model can overfit to those narrow conditions. During evaluation a single overall accuracy can hide gaps between groups.
In deployment errors can pile up quietly if I do not monitor them with the right breakdowns.

To reduce these risks, I would take specific steps at each stage.
- Data collection:
I would expand the dataset to include many subjects across skin tones, hand sizes, ages,
both hands, and a range of lighting and backgrounds. I would track counts so I know which groups are represented and where I am light.

- Model training:
I would use augmentations that match reality, including rotation, scale, translation, color changes,
slight blur or noise, and varied backgrounds, and keep classes balanced. I would compare backbones
such as ResNet 18 or MobileNetV3 and consider light fine tuning of the last
AlexNet block to adapt features to hands without overfitting.

- Evaluation:
I would report accuracy and confusion matrices by subgroup, not just overall.
For example, bins for lighting, background complexity, and when appropriate and respectful,
skin tone categories. If large gaps appear, I would adjust the data and training until the gaps narrow.

- Deployment and feedback:
I would add a low confidence fallback that asks for another photo or gives framing and
lighting tips, and I would collect user feedback on mistakes. I would log error cases and
confidence, review them on a schedule, and use those examples to update the dataset and retrain.

My goal is to treat fairness as an ongoing task. I plan to diversify and track the data, train under
more realistic conditions, evaluate by subgroup, and set up a feedback loop after release. These steps
are intended to improve reliability across users and give me a clear way to catch and fix issues over time.

'''
# Out:
# '\nPROVIDE YOUR ANSWER BELOW\n\nIf this model were used in the real world, the main risk I see is uneven performance across different users. \nBias could appear because of skin tone, hand size, age, left versus right hand, tattoos or jewelry, sleeves that\ncover part of the hand, and differences in lighting and background. If the training data leans toward clean, \nwell lit, centered, right hand photos from a small set of subjects, the system can look good on paper but fail\nmore often for people and environments it did not see. That creates unequal error rates across groups, which is unfair \nand can block communication in situations where people need the model to work.\n\nBias can enter at several points. During data collection it is easy to oversample ideal images and undersample real world variety. \nDuring training the model can overfit to those narrow conditions. During evaluation a single overall accuracy can hide gaps between groups. \nIn deployment errors can pile up quietly
# ...

# %% [markdown]
# # PART C (Optional) - Bonus Challenge!
#
# This is an optional exercise for those that finish the assignment early and would like to take on some additional challenging task.
#
# For this bonus challenge you are asked to explore different techniques to further improve the model for more realistic scenarios where the hands may be in front of various backgrounds, be taken at different scales, rotations, and positions in the image. To build a superior image classification model you can complete one or all of the following tasks.
#
# Tasks:
#
# 1. Test your best models (with or without transfer learning) on hand gestures images with backgrounds that are not clean and smooth. You can take your own hand gesture images, or find ones online to test your model. Comment on the performance of your model.
# 2. Generated additional data by performing data augmentation to replace the clean, smooth backgrounds with backgrounds with different textures. Do this on all your training, validation, and test data. This task can be done manually (could take a long time) or you can implement code that can automate the task. For Example, one approach you could take to automate this task is to use pretrained image segmentation tools to identify the hands in the images and crop them out and put them onto other backgrounds.
# 3. Improve on your data augmentation by applying scale, rotation, and translation transformations on different backgrounds.
# 4. Compare the performance of your best CNN models (with and without transfoer learning) trained with data augmentation to the results in 1. where you did not train on images with data augmentation.
# 5. Implement one of many region proposal tools to detect hand gestures in image frames and put a bounding box around the region with the highest confidence. You can use pretrained YOLO models, or a region proposal tool from openCV.
# 6. Create a short video demonstration how you can use your hand gesture recognition model to communicate a message using hand gestures.
#
# Bonus marks will be provided based on the number of steps completed. Summarize below your results and anything intersting you learned from the steps that you completed. Bonus marks cannot be accumulated beyond the maximum assignment grade.

# %%
# TO BE COMPLETED

# %%
'''
PROVIDE YOUR ANSWER BELOW






'''

# %% [markdown]
# ### Saving to HTML
# Detailed instructions for saving to HTML can be found <a href="https://stackoverflow.com/questions/53460051/convert-ipynb-notebook-to-html-in-google-colab/64487858#64487858">here</a>. Provided below are a summary of the instructions:
#
# (1) download your ipynb file by clicking on File->Download.ipynb
#
# (2) reupload your file to the temporary Google Colab storage (you can access the temporary storage from the tab to the left)
#
# (3) run the following:

# %%
# %%shell
# jupyter nbconvert --to html /content/A2_Hand_Gesture_Recognition.ipynb

# %% [markdown]
# (4) the html file will be available for download in the temporary Google Colab storage
#
# (5) review the html file and make sure all the results are visible before submitting your assignment to Quercus

# %% [markdown]
# # Assignment Grading Rubric
# The grading of the assignment will be based on the following categories:
#
# (0) **5 Pt - DATA** Generating new data to evaluate your model.
#
# (1) **9 Pt - EXPLORATORY QUESTIONS** These are basic questions that in most cases can be answered without requiring a fully working and trained neural network model. For example, data loading, processing and visualization, summary statistics, data exploration, model and training setup, etc.
#
# (2) **9 Pt - MODEL** Student has successfully implemented all the required neural network models and has demonstrated successful training of the model without any errors.
#
# (3) **9 Pt - RESULT** Students are evaluated based on the results achieved in comparison to the expected results of the assignment.
#
# (4) **9 Pt - DISCUSSION QUESTIONS** Student demonstrated understanding beyond the basic exploratory questions, can answer some of the more challenging questions, and provide arguments for their model selection decisions.
#
# (5) **9 Pt - COMMUNICATION** Student has provided a quality submission that is easy to read without too many unnecessary output statements that distract the reading of the document. The code has been well commented and all the answers are communicated clearly and concisely.
#
# (6) **5 Pt - BONUS** Student has completed the assignment and has taken on the challenging bonus tasks listed in PART C. The student has demonstrated a good understanding of all aspects of the assignment and has exceeded expectations for the assignment.
#
#
#
# **TOTAL GRADE = _____ of 50 Pts**
